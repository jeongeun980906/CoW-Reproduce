# %%
import pandas as pd
import numpy as np
from ithor_tools.objects import total
df = pd.read_csv('./res/out2.csv')

# %%
obj_score = []

for obj in total:
    temp = df.loc[df['query_name'] == obj, ['score']]
    temp = np.clip(temp,0,1)
    mean_score = temp.mean().item()
    mean_score = np.nan_to_num(mean_score,nan=100)
    if mean_score != 100:
        success_rate = (temp>0).sum().item()/(len(temp))
        obj_score.append(dict(object=obj,SPL=mean_score,success_rate = success_rate ))
obj_score = pd.DataFrame(obj_score)

# %%
spl = df['score'].to_numpy()
spl = np.clip(spl,a_min=0,a_max=1)
success = (spl>0)
mean_spl = spl.mean()
mean_success = success.mean()
temp = pd.DataFrame([dict(object='Average',SPL=mean_spl,success_rate=mean_success)])
total_obj_score = pd.concat((obj_score,temp))

# %%
total_obj_score
# Out:
#            object       SPL  success_rate
# 0           Apple  0.210977      0.733333
# 1       CellPhone  0.091605      0.666667
# 2   RemoteControl  0.064123      0.333333
# 3          Pillow  0.067508      0.315789
# 4      AlarmClock  0.156670      0.533333
# 5             Pot  0.106719      0.500000
# 6             Mug  0.074517      0.333333
# 7    PepperShaker  0.363020      0.666667
# 8              CD  0.000000      0.000000
# 9          Laptop  0.276751      0.600000
# 10      TeddyBear  0.538788      1.000000
# 11           Book  0.098329      0.347826
# 12    SprayBottle  0.272098      0.600000
# 0         Average  0.140749      0.467742
